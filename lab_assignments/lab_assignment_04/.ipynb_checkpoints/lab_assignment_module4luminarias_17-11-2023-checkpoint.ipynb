# %% [markdown]
# # **AP155 Lab Assignment**
# ## Module 4: Ordinary Differential Equations
#
# _Instructions_: Answer each problem as completely as you can. Discuss **all** your answers as clearly and concisely as possible.
#
# _Scoring Criteria_: 50% - *correctness of code*; 50% - *discussion of the code and results*. Maximum score is **100 points**.

# %% [markdown]
# ### Student Information
#
# _Full Name (Last Name, First Name)_: Mark Joseph Luminarias\
# _Student No._: 2019-08483\
# _Section_:

# %% [markdown]
# ### Submission Information
#
# _Date and Time Submitted (most recent upload)_:
#
# **HONOR PLEDGE** I affirm that I have upheld the highest principles of honesty and integrity in my academic work and that this lab assignment is my own work.
#
# **Sign here with your full name:**

# %% [markdown]
# ### Grading Information (c/o Lab Instructor)
#
# TOTAL SCORE: **[]**/100
#
# Score breakdown:
# * Problem 1 - 37/50
# * Problem 2 - 37/50
#
# _Date and Time Scored (MM/DD/YYYY HH:MM AM/PM):_

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from numpy import arange, array, pi, sin
from matplotlib.pyplot import plot, legend, show, xlabel, ylabel

# %% [markdown]
# ### PROBLEM 1
# **The Lotka-Volterra equations**
#
# _Refer to Exercise 8.2 in the Newman text._ The Lotka-Volterra equations are a mathematical model of predator-prey interactions between biological species. Let two variables $x$ and $y$ be proportional to the size of the populations of two species, traditionally called "rabbits" (the prey) and "foxes" (the predators). You could think of $x$ and $y$ as being the population in thousands, say, so that $x = 2$ means there are 2000 rabbits.
#
# In the Lotka-Volterra model the rabbits reproduce at a rate proportional to their population, but are eaten by the foxes at a rate proportional to both their own population and the population of foxes:
#
# $$\frac{{\rm d}x}{{\rm d}t} = \alpha x - \beta xy,$$
#
# where $\alpha$ and $\beta$ are constants. At the same time the foxes reproduce at a rate proportional to the rate at which they eat rabbits-- because they need food to grow and reproduce-- but also die of old age at a rate proportional to their own population:
#
# $$\frac{{\rm d}y}{{\rm d}t}  = \gamma xy - \delta y,$$
#
# where $\gamma$ and $\delta$ are also constants. *(25 pts.)*
#
# 1. Solve these equations using the fourth-order Runge-Kutta method for the case $\alpha = 1, \beta = \gamma = 0.5$, and $\delta = 2$, starting from the initial condition $x = y = 2$.
#
# 2. Make a graph showing both $x$ and $y$ as a function of time on the same axes from $t =0$ to $t = 30$. *(25 pts.)*

# %%
# Assign constants
alpha = 1
beta = 0.5
gamma = 0.5
delta = 2

# Define fucntion f(r,t)
def f(r,t):
    x = r[0]
    y = r[1]
    fx = alpha*x - beta*x*y
    fy = gamma*x*y - delta*y
    return array([fx,fy],float)

# Designate initial and final time of interest
a = 0                 # Initial time t (in seconds)
b = 30                # Final time t (in seconds) 
N = 1000              # Number of steps
h = (b-a)/N           # step length

# Array for plotting points
tpoints = arange(a,b,h)
xpoints = []
ypoints = []

# Initial value of x,y
r = array([2.0,2.0],float)
# Main Loop
for t in tpoints:
    xpoints.append(r[0])
    ypoints.append(r[1])
    # Runge-Kutta Method
    k1 = h*f(r,t)
    k2 = h*f(r+0.5*k1, t+0.5*h)
    k3 = h*f(r+0.5*k2, t+0.5*h)
    k4 = h*f(r+k3, t+h)
    r +=(k1 + 2*k2 + 2*k3 + k4)/6

# Plotting
plt.title("Lotka-Volterra System of rabbits and foxes")
plot(tpoints,xpoints,'g', label ="rabbits")
plot(tpoints,ypoints,'y', label ="foxes")
plt.xlabel("t (in seconds)")
plt.ylabel("population (in $10^3$)")
legend(loc = 'upper right')
show()

# %% [markdown]
# <span style="color:blue"> Discussion of results? </span>

# %% [markdown]
# ### PROBLEM 2
#
# **Nonlinear pendulum**
#
# _Refer to Exercise 8.4 in the Newman text._ Building on the results from Example 8.6, calculate the motion of a nonlinear pendulum as follows.
#
# 1. Solve the two first-order equations, Eqs. (8.45) and (8.46), using the fourth-order Runge-Kutta method for a pendulum with a 10 cm arm. Use your program to calculate the angle $\theta$ of displacement for several periods of the pendulum when it is released from a standstill at $\theta = 179^\circ$ from the vertical. *(25 pts.)*
#
# 2. Make a graph of $\theta$ as a function of time. *(25 pts.)*

# %%
g = 9.81          # Gravitational constant
l = 10.0          # String length (in centimeters)

def f(r,t):
    theta = r[0]
    omega = r[1]
    ftheta = omega
    fomega = -(g/l)*sin(theta)
    return array ([ftheta, fomega],float)

# Designate initial and final time of interest
a = 0                 # Initial time t (in seconds)
b = 90                # Final time t (in seconds) 
N = 1000              # Number of steps
h = (b-a)/N           # step length
theta0 = 179*(pi/180) # converts degrees in radians

# Array for plotting points
tpoints = arange(a,b,h)
theta_points = []
omega_points = []

# Initial value of x,y
r = array([theta0,0.0],float)
# Main Loop
for t in tpoints:
    theta_points.append(r[0])
    omega_points.append(r[1])
    # Runge-Kutta Method
    k1 = h*f(r,t)
    k2 = h*f(r+0.5*k1, t+0.5*h)
    k3 = h*f(r+0.5*k2, t+0.5*h)
    k4 = h*f(r+k3, t+h)
    r +=(k1 + 2*k2 + 2*k3 + k4)/6

# The solution can be placed in array such that
# it will display the corresponding displacement angle
# for time t
theta_sol = np.array((tpoints,theta_points)).T

# The solution can be shown using
print("Solution (t (secs), \u03B8 (radians)): ","\n",theta_sol)    
    
# Plotting
plt.title("Angle of displacement \u03B8 of Nonlinear Pendulum")
plot(tpoints,theta_points,'g', label ="theta")
plt.xlabel("t (in seconds)")
plt.ylabel("\u03B8 in radians")
show()
# Out:
# Solution (t (secs), θ (radians)):
#  [[ 0.          3.12413936]
#  [ 0.09        3.12406998]
#  [ 0.18        3.12386127]
#  ...
#  [89.73       -2.93806061]
#  [89.82       -2.91918993]
#  [89.91       -2.89856547]]

# %% [markdown]
# <span style="color:blue"> Also: discussion of results? </span>
